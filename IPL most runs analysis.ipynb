# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\acer.DESKTOP-1VQGBE7\OneDrive\Desktop\Pandas datasets\most_runs_average_strikerate.csv")
df
# Out:
#             batsman  total_runs  out  numberofballs    average  strikerate
# 0           V Kohli        5426  152           4111  35.697368  131.987351
# 1          SK Raina        5386  160           3916  33.662500  137.538304
# 2         RG Sharma        4902  161           3742  30.447205  130.999466
# 3         DA Warner        4717  114           3292  41.377193  143.286756
# 4          S Dhawan        4601  137           3665  33.583942  125.538881
# ..              ...         ...  ...            ...        ...         ...
# 511        ND Doshi           0    1             13   0.000000    0.000000
# 512         J Denly           0    1              1   0.000000    0.000000
# 513         S Ladda           0    2              9   0.000000    0.000000
# 514  V Pratap Singh           0    1              1   0.000000    0.000000
# 515       S Kaushik           0    1              1   0.000000    0.000000
#
# [516 rows x 6 columns]

# %%
df.head(10)
# Out:
#           batsman  total_runs  out  numberofballs    average  strikerate
# 0         V Kohli        5426  152           4111  35.697368  131.987351
# 1        SK Raina        5386  160           3916  33.662500  137.538304
# 2       RG Sharma        4902  161           3742  30.447205  130.999466
# 3       DA Warner        4717  114           3292  41.377193  143.286756
# 4        S Dhawan        4601  137           3665  33.583942  125.538881
# 5        CH Gayle        4525  110           2972  41.136364  152.254374
# 6        MS Dhoni        4450  118           3206  37.711864  138.802246
# 7      RV Uthappa        4420  156           3381  28.333333  130.730553
# 8  AB de Villiers        4414  104           2902  42.442308  152.101999
# 9       G Gambhir        4219  134           3400  31.485075  124.088235

# %%
df.tail(10)
# Out:
#             batsman  total_runs  out  numberofballs  average  strikerate
# 506      RR Bhatkal           0    2              2      0.0         0.0
# 507       IC Pandey           0    1              2      0.0         0.0
# 508        L Ablish           0    0              2      NaN         0.0
# 509    Abdur Razzak           0    0              2      NaN         0.0
# 510     Sunny Gupta           0    1              1      0.0         0.0
# 511        ND Doshi           0    1             13      0.0         0.0
# 512         J Denly           0    1              1      0.0         0.0
# 513         S Ladda           0    2              9      0.0         0.0
# 514  V Pratap Singh           0    1              1      0.0         0.0
# 515       S Kaushik           0    1              1      0.0         0.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 516 entries, 0 to 515
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   batsman        516 non-null    object
#  1   total_runs     516 non-null    int64
#  2   out            516 non-null    int64
#  3   numberofballs  516 non-null    int64
#  4   average        482 non-null    float64
#  5   strikerate     516 non-null    float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 24.3+ KB

# %%
df.isnull().sum()
# Out:
# batsman           0
# total_runs        0
# out               0
# numberofballs     0
# average          34
# strikerate        0
# dtype: int64

# %%
df = df.dropna(subset = 'average')
df
# Out:
#             batsman  total_runs  out  numberofballs    average  strikerate
# 0           V Kohli        5426  152           4111  35.697368  131.987351
# 1          SK Raina        5386  160           3916  33.662500  137.538304
# 2         RG Sharma        4902  161           3742  30.447205  130.999466
# 3         DA Warner        4717  114           3292  41.377193  143.286756
# 4          S Dhawan        4601  137           3665  33.583942  125.538881
# ..              ...         ...  ...            ...        ...         ...
# 511        ND Doshi           0    1             13   0.000000    0.000000
# 512         J Denly           0    1              1   0.000000    0.000000
# 513         S Ladda           0    2              9   0.000000    0.000000
# 514  V Pratap Singh           0    1              1   0.000000    0.000000
# 515       S Kaushik           0    1              1   0.000000    0.000000
#
# [482 rows x 6 columns]

# %%
df[df['total_runs'] > 4000].sort_values(by = 'total_runs',ascending = False)
# Out:
#           batsman  total_runs  out  numberofballs    average  strikerate
# 0         V Kohli        5426  152           4111  35.697368  131.987351
# 1        SK Raina        5386  160           3916  33.662500  137.538304
# 2       RG Sharma        4902  161           3742  30.447205  130.999466
# 3       DA Warner        4717  114           3292  41.377193  143.286756
# 4        S Dhawan        4601  137           3665  33.583942  125.538881
# 5        CH Gayle        4525  110           2972  41.136364  152.254374
# 6        MS Dhoni        4450  118           3206  37.711864  138.802246
# 7      RV Uthappa        4420  156           3381  28.333333  130.730553
# 8  AB de Villiers        4414  104           2902  42.442308  152.101999
# 9       G Gambhir        4219  134           3400  31.485075  124.088235

# %%
df.groupby('out').agg({'total_runs':['sum','max','min','count','mean'],'numberofballs':['sum','max','min','count','mean'],'batsman':['count'],
                       'strikerate':['sum','max','min','count','mean']})
# Out:
#     total_runs                                numberofballs                    \
#            sum   max   min count         mean           sum   max   min count
# out
# 1          703    88     0    76     9.250000           842    83     1    76
# 2         1025    62     0    57    17.982456          1101    53     2    57
# 3         1521   167     3    44    34.568182          1569   132     8    44
# 4         1353   203     2    21    64.428571          1158   156    10    21
# 5         1990   183    13    26    76.538462          1831   135    23    26
# 6         1766   205    20    17   103.882353          1442   148    29    17
# 7         2409   193    24    24   100.375000          2159   161    39    24
# 8         2312   459    41    17   136.000000          1961   284    46    17
# 9         1609   196    26    13   123.769231          1361   172    47    13
# 10        1815   302    16    11   165.000000          1414   193    44    11
# ...

# %%
df
# Out:
#             batsman  total_runs  numberofballs    average  strikerate
# out
# 152         V Kohli        5426           4111  35.697368  131.987351
# 160        SK Raina        5386           3916  33.662500  137.538304
# 161       RG Sharma        4902           3742  30.447205  130.999466
# 114       DA Warner        4717           3292  41.377193  143.286756
# 137        S Dhawan        4601           3665  33.583942  125.538881
# ..              ...         ...            ...        ...         ...
# 1          ND Doshi           0             13   0.000000    0.000000
# 1           J Denly           0              1   0.000000    0.000000
# 2           S Ladda           0              9   0.000000    0.000000
# 1    V Pratap Singh           0              1   0.000000    0.000000
# 1         S Kaushik           0              1   0.000000    0.000000
#
# [482 rows x 5 columns]

# %%
df.loc[df.index > 100].plot.pie(y = 'total_runs',figsize = (10,10))
# Out:
# <Axes: ylabel='total_runs'>

# %%
df.boxplot(grid = True,figsize = (10,10),rot = 45)
# Out:
# <Axes: >
