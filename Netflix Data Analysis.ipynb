# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\acer.DESKTOP-1VQGBE7\OneDrive\Desktop\My datasets\netflix_titles.csv")
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water              NaN
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans              NaN
# 4         s5  TV Show           Kota Factory              NaN
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb              NaN
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                                   NaN  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df.head(10)
# Out:
#   show_id     type                             title  \
# 0      s1    Movie              Dick Johnson Is Dead
# 1      s2  TV Show                     Blood & Water
# 2      s3  TV Show                         Ganglands
# 3      s4  TV Show             Jailbirds New Orleans
# 4      s5  TV Show                      Kota Factory
# 5      s6  TV Show                     Midnight Mass
# 6      s7    Movie  My Little Pony: A New Generation
# 7      s8    Movie                           Sankofa
# 8      s9  TV Show     The Great British Baking Show
# 9     s10    Movie                      The Starling
#
#                         director  \
# 0                Kirsten Johnson
# 1                            NaN
# 2                Julien Leclercq
# 3                            NaN
# 4                            NaN
# 5                  Mike Flanagan
# 6  Robert Cullen, José Luis Ucha
# 7                   Haile Gerima
# 8                Andy Devonshire
# 9                 Theodore Melfi
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
df.isnull().sum()
# Out:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
df['director'] = df['director'].fillna('No Record')
df['cast'] = df['cast'].fillna('No Record')
df
# Out:
#      show_id     type                  title         director  \
# 0         s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show          Blood & Water        No Record
# 2         s3  TV Show              Ganglands  Julien Leclercq
# 3         s4  TV Show  Jailbirds New Orleans        No Record
# 4         s5  TV Show           Kota Factory        No Record
# ...      ...      ...                    ...              ...
# 8802   s8803    Movie                 Zodiac    David Fincher
# 8803   s8804  TV Show            Zombie Dumb        No Record
# 8804   s8805    Movie             Zombieland  Ruben Fleischer
# 8805   s8806    Movie                   Zoom     Peter Hewitt
# 8806   s8807    Movie                 Zubaan      Mozez Singh
#
#                                                    cast        country  \
# 0                                             No Record  United States
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# ...

# %%
df = df.dropna(subset = 'country')
df = df.dropna(subset = 'rating')
df
# Out:
#      show_id     type                          title         director  \
# 0         s1    Movie           Dick Johnson Is Dead  Kirsten Johnson
# 1         s2  TV Show                  Blood & Water        No Record
# 4         s5  TV Show                   Kota Factory        No Record
# 7         s8    Movie                        Sankofa     Haile Gerima
# 8         s9  TV Show  The Great British Baking Show  Andy Devonshire
# ...      ...      ...                            ...              ...
# 8801   s8802    Movie                        Zinzana  Majid Al Ansari
# 8802   s8803    Movie                         Zodiac    David Fincher
# 8804   s8805    Movie                     Zombieland  Ruben Fleischer
# 8805   s8806    Movie                           Zoom     Peter Hewitt
# 8806   s8807    Movie                         Zubaan      Mozez Singh
#
#                                                    cast  \
# 0                                             No Record
# ...

# %%
df.reset_index(inplace = True)
df
# Out:
#       index show_id     type                          title         director  \
# 0         0      s1    Movie           Dick Johnson Is Dead  Kirsten Johnson
# 1         1      s2  TV Show                  Blood & Water        No Record
# 2         4      s5  TV Show                   Kota Factory        No Record
# 3         7      s8    Movie                        Sankofa     Haile Gerima
# 4         8      s9  TV Show  The Great British Baking Show  Andy Devonshire
# ...     ...     ...      ...                            ...              ...
# 7968   8801   s8802    Movie                        Zinzana  Majid Al Ansari
# 7969   8802   s8803    Movie                         Zodiac    David Fincher
# 7970   8804   s8805    Movie                     Zombieland  Ruben Fleischer
# 7971   8805   s8806    Movie                           Zoom     Peter Hewitt
# 7972   8806   s8807    Movie                         Zubaan      Mozez Singh
#
# ...

# %%
df.groupby('type').count() #Number of movies vs TV Shows
# Out:
#          index  show_id  title  director  cast  country  date_added  \
# type
# Movie     5690     5690   5690      5690  5690     5690        5690
# TV Show   2283     2283   2283      2283  2283     2283        2274
#
#          release_year  rating  duration  listed_in  description
# type
# Movie            5690    5690      5687       5690         5690
# TV Show          2283    2283      2283       2283         2283

# %%
df.head(10).sort_values(by = 'release_year') #Top 10 by oldest year
# Out:
#    index show_id     type                          title             director  \
# 3      7      s8    Movie                        Sankofa         Haile Gerima
# 9     21     s22  TV Show         Resurrection: Ertugrul            No Record
# 0      0      s1    Movie           Dick Johnson Is Dead      Kirsten Johnson
# 8     17     s18  TV Show                Falsa identidad            No Record
# 1      1      s2  TV Show                  Blood & Water            No Record
# 2      4      s5  TV Show                   Kota Factory            No Record
# 4      8      s9  TV Show  The Great British Baking Show      Andy Devonshire
# 5      9     s10    Movie                   The Starling       Theodore Melfi
# 6     12     s13    Movie                   Je Suis Karl  Christian Schwochow
# 7     15     s16  TV Show              Dear White People            No Record
#
#                                                 cast  \
# 3  Kofi Ghanaba, Oyafunmike Ogunlano, Alexandra D...
# ...

# %%
df.groupby('listed_in').count().sort_values(by = 'type',ascending = False)
# Out:
#                                                     index  show_id  type  \
# listed_in
# Documentaries                                         343      343   343
# Dramas, International Movies                          337      337   337
# Stand-Up Comedy                                       303      303   303
# Comedies, Dramas, International Movies                260      260   260
# Dramas, Independent Movies, International Movies      243      243   243
# ...                                                   ...      ...   ...
# Cult Movies, Dramas, Music & Musicals                   1        1     1
# Cult Movies, Dramas, Thrillers                          1        1     1
# Cult Movies, Horror Movies, Thrillers                   1        1     1
# Cult Movies, Independent Movies, Thrillers              1        1     1
# Crime TV Shows, TV Action & Adventure, TV Sci-F...      1        1     1
#
#                                                     title  director  cast  \
# ...

# %%
df.groupby('rating').count().sort_values(by = 'type',ascending = False)
# Out:
#           index  show_id  type  title  director  cast  country  date_added  \
# rating
# TV-MA      2931     2931  2931   2931      2931  2931     2931        2929
# TV-14      1930     1930  1930   1930      1930  1930     1930        1927
# R           788      788   788    788       788   788      788         788
# TV-PG       773      773   773    773       773   773      773         771
# PG-13       482      482   482    482       482   482      482         482
# PG          281      281   281    281       281   281      281         281
# TV-Y7       236      236   236    236       236   236      236         235
# TV-Y        227      227   227    227       227   227      227         227
# TV-G        190      190   190    190       190   190      190         190
# NR           80       80    80     80        80    80       80          79
# G            41       41    41     41        41    41       41          41
# ...

# %%
df.set_index('rating',inplace = True)
df
# Out:
#         index show_id     type                          title  \
# rating
# PG-13       0      s1    Movie           Dick Johnson Is Dead
# TV-MA       1      s2  TV Show                  Blood & Water
# TV-MA       4      s5  TV Show                   Kota Factory
# TV-MA       7      s8    Movie                        Sankofa
# TV-14       8      s9  TV Show  The Great British Baking Show
# ...       ...     ...      ...                            ...
# TV-MA    8801   s8802    Movie                        Zinzana
# R        8802   s8803    Movie                         Zodiac
# R        8804   s8805    Movie                     Zombieland
# PG       8805   s8806    Movie                           Zoom
# TV-14    8806   s8807    Movie                         Zubaan
#
#                director                                               cast  \
# rating
# PG-13   Kirsten Johnson                                          No Record
# ...

# %%
df.plot(kind = 'bar')
# Out:
# <Axes: xlabel='rating'>
