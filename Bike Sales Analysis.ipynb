# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\acer.DESKTOP-1VQGBE7\OneDrive\Desktop\Power BI datasets\Sales.csv")
df
# Out:
#               Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0       2013-11-26   26  November  2013            19     Youth (<25)
# 1       2015-11-26   26  November  2015            19     Youth (<25)
# 2       2014-03-23   23     March  2014            49  Adults (35-64)
# 3       2016-03-23   23     March  2016            49  Adults (35-64)
# 4       2014-05-15   15       May  2014            47  Adults (35-64)
# ...            ...  ...       ...   ...           ...             ...
# 113031  2016-04-12   12     April  2016            41  Adults (35-64)
# 113032  2014-04-02    2     April  2014            18     Youth (<25)
# 113033  2016-04-02    2     April  2016            18     Youth (<25)
# 113034  2014-03-04    4     March  2014            37  Adults (35-64)
# 113035  2016-03-04    4     March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %%
df.drop_duplicates()
# Out:
#               Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0       2013-11-26   26  November  2013            19     Youth (<25)
# 1       2015-11-26   26  November  2015            19     Youth (<25)
# 2       2014-03-23   23     March  2014            49  Adults (35-64)
# 3       2016-03-23   23     March  2016            49  Adults (35-64)
# 4       2014-05-15   15       May  2014            47  Adults (35-64)
# ...            ...  ...       ...   ...           ...             ...
# 113031  2016-04-12   12     April  2016            41  Adults (35-64)
# 113032  2014-04-02    2     April  2014            18     Youth (<25)
# 113033  2016-04-02    2     April  2016            18     Youth (<25)
# 113034  2014-03-04    4     March  2014            37  Adults (35-64)
# 113035  2016-03-04    4     March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113036 entries, 0 to 113035
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Date              113036 non-null  object
#  1   Day               113036 non-null  int64
#  2   Month             113036 non-null  object
#  3   Year              113036 non-null  int64
#  4   Customer_Age      113036 non-null  int64
#  5   Age_Group         113036 non-null  object
#  6   Customer_Gender   113036 non-null  object
#  7   Country           113036 non-null  object
#  8   State             113036 non-null  object
#  9   Product_Category  113036 non-null  object
#  10  Sub_Category      113036 non-null  object
#  11  Product           113036 non-null  object
#  12  Order_Quantity    113036 non-null  int64
#  13  Unit_Cost         113036 non-null  int64
#  14  Unit_Price        113036 non-null  int64
#  15  Profit            113036 non-null  int64
# ...

# %%
# Top spending customers
df.groupby(['Customer_Gender','Age_Group']).agg({'Profit':'sum'}).sort_values(by = 'Profit',ascending = False)
# Out:
#                                        Profit
# Customer_Gender Age_Group
# M               Adults (35-64)        8204915
# F               Adults (35-64)        8116667
# M               Young Adults (25-34)  5811264
# F               Young Adults (25-34)  5575497
# M               Youth (<25)           2397943
# F               Youth (<25)           1976649
# M               Seniors (64+)           73110
# F               Seniors (64+)           65055

# %%
# Average Order size per age group
df.groupby('Age_Group').agg({'Order_Quantity':'mean'}).sort_values(by = 'Order_Quantity')
# Out:
#                       Order_Quantity
# Age_Group
# Young Adults (25-34)       11.560899
# Adults (35-64)             12.045303
# Youth (<25)                12.124018
# Seniors (64+)              13.530137

# %%
# Top 10 Products
df.groupby('Sub_Category').agg({'Revenue':'sum'}).sort_values(by = 'Revenue',ascending = False).head(10).plot(kind = 'pie',y = 'Revenue',figsize = (8,8))
# Out:
# <Axes: ylabel='Revenue'>

# %%
# Country wise revenue
df.groupby('Country').agg({'Revenue':'mean'}).plot(kind = 'bar')
# Out:
# <Axes: xlabel='Country'>

# %%
df.groupby('State').agg({'Profit':'mean'}).sort_values(by = 'Profit',ascending = False).head(5)
# Out:
#                     Profit
# State
# Arizona        1069.750000
# Massachusetts   776.000000
# Wyoming         695.625000
# Alberta         416.964286
# Bayern          404.411641

# %%
order_quantity_value = df.groupby('Age_Group').agg({'Order_Quantity':'mean'}).sort_values(by = 'Order_Quantity')

print(order_quantity_value)
# Out:
#                       Order_Quantity
# Age_Group
# Young Adults (25-34)       11.560899
# Adults (35-64)             12.045303
# Youth (<25)                12.124018
# Seniors (64+)              13.530137

# %%
# Percentage change
order_quantity_value['pct_change'] = order_quantity_value['Order_Quantity'].pct_change() * 100

print(order_quantity_value)
# Out:
#                       Order_Quantity  pct_change
# Age_Group
# Young Adults (25-34)       11.560899         NaN
# Adults (35-64)             12.045303    4.190019
# Youth (<25)                12.124018    0.653494
# Seniors (64+)              13.530137   11.597793
