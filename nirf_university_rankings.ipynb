# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\acer.DESKTOP-1VQGBE7\OneDrive\Desktop\Pandas datasets\nirf_university_rankings.csv")
df
# Out:
#    Institute_id                                               name  \
# 0   IR-O-U-0220  Indian Institute of Science, BengaluruMore Det...
# 1   IR-O-U-0109        Jawaharlal Nehru UniversityMore Details | |
# 2   IR-O-U-0108               Jamia Millia IslamiaMore Details | |
# 3   IR-O-U-0234  Manipal Academy of Higher Education, ManipalMo...
# 4   IR-O-U-0500           Banaras Hindu UniversityMore Details | |
# ..          ...                                                ...
# 95  IR-O-U-0489  Vel Tech Rangarajan Dr. Sagunthala R & D Insti...
# 96  IR-O-U-0524              University of LucknowMore Details | |
# 97  IR-O-U-0444  Avinashilingam Institute for Home Science and ...
# 98  IR-O-U-0449   Central University of Tamil NaduMore Details | |
# 99  IR-O-C-6379  Netaji Subhas University of Technology (NSUT)M...
#
#           city          state  Score  ranking
# 0    Bengaluru      Karnataka  83.29        1
# 1    New Delhi          Delhi  69.80        2
# ...

# %%
df.drop_duplicates()
# Out:
#    Institute_id                                               name  \
# 0   IR-O-U-0220  Indian Institute of Science, BengaluruMore Det...
# 1   IR-O-U-0109        Jawaharlal Nehru UniversityMore Details | |
# 2   IR-O-U-0108               Jamia Millia IslamiaMore Details | |
# 3   IR-O-U-0234  Manipal Academy of Higher Education, ManipalMo...
# 4   IR-O-U-0500           Banaras Hindu UniversityMore Details | |
# ..          ...                                                ...
# 95  IR-O-U-0489  Vel Tech Rangarajan Dr. Sagunthala R & D Insti...
# 96  IR-O-U-0524              University of LucknowMore Details | |
# 97  IR-O-U-0444  Avinashilingam Institute for Home Science and ...
# 98  IR-O-U-0449   Central University of Tamil NaduMore Details | |
# 99  IR-O-C-6379  Netaji Subhas University of Technology (NSUT)M...
#
#           city          state  Score  ranking
# 0    Bengaluru      Karnataka  83.29        1
# 1    New Delhi          Delhi  69.80        2
# ...

# %%
df.isnull().sum()
# Out:
# Institute_id    0
# name            0
# city            0
# state           0
# Score           0
# ranking         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Institute_id  100 non-null    object
#  1   name          100 non-null    object
#  2   city          100 non-null    object
#  3   state         100 non-null    object
#  4   Score         100 non-null    float64
#  5   ranking       100 non-null    int64
# dtypes: float64(1), int64(1), object(4)
# memory usage: 4.8+ KB

# %%
df.head(10)
# Out:
#   Institute_id                                               name        city  \
# 0  IR-O-U-0220  Indian Institute of Science, BengaluruMore Det...   Bengaluru
# 1  IR-O-U-0109        Jawaharlal Nehru UniversityMore Details | |   New Delhi
# 2  IR-O-U-0108               Jamia Millia IslamiaMore Details | |   New Delhi
# 3  IR-O-U-0234  Manipal Academy of Higher Education, ManipalMo...     Manipal
# 4  IR-O-U-0500           Banaras Hindu UniversityMore Details | |    Varanasi
# 5  IR-O-U-0120                University of DelhiMore Details | |       Delhi
# 6  IR-O-U-0436         Amrita Vishwa VidyapeethamMore Details | |  Coimbatore
# 7  IR-O-U-0496          Aligarh Muslim UniversityMore Details | |     Aligarh
# 8  IR-O-U-0575                Jadavpur UniversityMore Details | |     Kolkata
# 9  IR-O-U-0490    Vellore Institute of TechnologyMore Details | |     Vellore
#
#            state  Score  ranking
# 0      Karnataka  83.29        1
# 1          Delhi  69.80        2
# ...

# %%
df[df['city'] == 'New Delhi'].sort_values(by = 'ranking')
# Out:
#    Institute_id                                               name       city  \
# 1   IR-O-U-0109        Jawaharlal Nehru UniversityMore Details | |  New Delhi
# 2   IR-O-U-0108               Jamia Millia IslamiaMore Details | |  New Delhi
# 40  IR-O-U-0107                      Jamia HamdardMore Details | |  New Delhi
# 47  IR-O-U-0098     Delhi Technological UniversityMore Details | |  New Delhi
# 79  IR-O-U-0099  Guru Gobind Singh Indraprastha UniversityMore ...  New Delhi
#
#     state  Score  ranking
# 1   Delhi  69.80        2
# 2   Delhi  68.11        3
# 40  Delhi  54.86       40
# 47  Delhi  53.31       48
# 79  Delhi  47.66       80

# %%
df.groupby('city').agg({'Institute_id':'count'}).rename(columns={'Institute_id':'count'}).sort_values(by = 'count', ascending = False).head(10)
# Out:
#              count
# city
# Chennai          8
# Mumbai           5
# Bengaluru        5
# New Delhi        5
# Pune             4
# Coimbatore       4
# Lucknow          3
# Hyderabad        3
# Bhubaneswar      2
# Mangaluru        2

# %%
df
# Out:
#    Institute_id                                               name  \
# 0   IR-O-U-0220  Indian Institute of Science, BengaluruMore Det...
# 1   IR-O-U-0109        Jawaharlal Nehru UniversityMore Details | |
# 2   IR-O-U-0108               Jamia Millia IslamiaMore Details | |
# 3   IR-O-U-0234  Manipal Academy of Higher Education, ManipalMo...
# 4   IR-O-U-0500           Banaras Hindu UniversityMore Details | |
# ..          ...                                                ...
# 95  IR-O-U-0489  Vel Tech Rangarajan Dr. Sagunthala R & D Insti...
# 96  IR-O-U-0524              University of LucknowMore Details | |
# 97  IR-O-U-0444  Avinashilingam Institute for Home Science and ...
# 98  IR-O-U-0449   Central University of Tamil NaduMore Details | |
# 99  IR-O-C-6379  Netaji Subhas University of Technology (NSUT)M...
#
#           city          state  Score  ranking
# 0    Bengaluru      Karnataka  83.29        1
# 1    New Delhi          Delhi  69.80        2
# ...

# %%
df.groupby('state').agg({'Score':'mean'}).sort_values('Score', ascending = False).head(10).plot(kind = 'pie',y = 'Score',figsize = (8,8),title = 'Top 10 States with highest Avg Score')
# Out:
# <Axes: title={'center': 'Top 10States with highest Avg Score'}, ylabel='Score'>

# %%
df
# Out:
#    Institute_id                                               name  \
# 0   IR-O-U-0220  Indian Institute of Science, BengaluruMore Det...
# 1   IR-O-U-0109        Jawaharlal Nehru UniversityMore Details | |
# 2   IR-O-U-0108               Jamia Millia IslamiaMore Details | |
# 3   IR-O-U-0234  Manipal Academy of Higher Education, ManipalMo...
# 4   IR-O-U-0500           Banaras Hindu UniversityMore Details | |
# ..          ...                                                ...
# 95  IR-O-U-0489  Vel Tech Rangarajan Dr. Sagunthala R & D Insti...
# 96  IR-O-U-0524              University of LucknowMore Details | |
# 97  IR-O-U-0444  Avinashilingam Institute for Home Science and ...
# 98  IR-O-U-0449   Central University of Tamil NaduMore Details | |
# 99  IR-O-C-6379  Netaji Subhas University of Technology (NSUT)M...
#
#           city          state  Score  ranking
# 0    Bengaluru      Karnataka  83.29        1
# 1    New Delhi          Delhi  69.80        2
# ...

# %%
df.groupby('state').agg({'city':['count']}).plot(kind = 'bar')
# Out:
# <Axes: xlabel='state'>

# %%
df.set_index(['state','city'],inplace = True)
df
# Out:
#                           index Institute_id  \
# state         city
# Karnataka     Bengaluru       0  IR-O-U-0220
# Delhi         New Delhi       1  IR-O-U-0109
#               New Delhi       2  IR-O-U-0108
# Karnataka     Manipal         3  IR-O-U-0234
# Uttar Pradesh Varanasi        4  IR-O-U-0500
# ...                         ...          ...
# Tamil Nadu    Chennai        95  IR-O-U-0489
# Uttar Pradesh Lucknow        96  IR-O-U-0524
# Tamil Nadu    Coimbatore     97  IR-O-U-0444
#               Tiruvarur      98  IR-O-U-0449
# Delhi         Delhi          99  IR-O-C-6379
#
#                                                                        name  \
# state         city
# Karnataka     Bengaluru   Indian Institute of Science, BengaluruMore Det...
# Delhi         New Delhi         Jawaharlal Nehru UniversityMore Details | |
#               New Delhi                Jamia Millia IslamiaMore Details | |
# ...
